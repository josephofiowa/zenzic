# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.image as mpimg
from PIL import Image
#import cv2

# %%
# %matplotlib inline

# %% [markdown]
# Using Matplotlib

# %%
img=mpimg.imread('./img/DMI-Skyline.jpg')

# %%
imgplot = plt.imshow(img)

# %%
lum_img = img[:,:,0]

# %%
plt.imshow(lum_img)

# %%
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'_classic_test',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn',
#  u'seaborn-dark-palette']

# %%
plt.style.use('fivethirtyeight')

# %%
imgplot = plt.imshow(img)

# %% [markdown]
# Using PIL

# %%
image = Image.open('./img/DMI-Skyline.jpg')

# %%
mask=image.convert("L")

# %%
th=150 # the value has to be adjusted for an image of interest

# %%
mask = mask.point(lambda i: i < th and 255)

# %%
mask
# Out:
# <PIL.Image.Image image mode=L size=3240x834 at 0x1048E6910>

# %%
#mask.save(file_where_to_save_result)

# %% [markdown]
# Edge Detection

# %%
img = cv2.imread('./img/DMI-Skyline.jpg',0)
edges = cv2.Canny(img,100,200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5a3ab2963388> in <module>()
# ----> 1 img = cv2.imread('./img/DMI-Skyline.jpg',0)
#       2 edges = cv2.Canny(img,100,200)
#
# NameError: name 'cv2' is not defined

# %%
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
