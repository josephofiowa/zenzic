# %%
import random
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from scipy.misc import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
obama = pd.read_csv('../obama_cleaned.csv')

# %%
all_text = []
for x in obama.body:
    all_text.append(x)

# %%
text = unicode(all_text)

# %%
len(text)
# Out:
# 623270

# %%
mask = imread('theonion_logo_inverted.png')

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(10, 50)

# %%
def green_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(135, 60%%, %d%%)" % random.randint(20, 60)

# %%
# wc = WordCloud(background_color='white', mask=yelp_mask, stopwords=STOPWORDS)
# wc.generate(text)
wc = WordCloud(max_words=300, background_color='white', mask=mask, stopwords=STOPWORDS, margin=10,
               random_state=1).generate(text)

# %%
onion_coloring = np.array(Image.open("theonion_logo_inverted.png"))
stopwords = set(STOPWORDS)
# stopwords.add("said")

# %%
wc = WordCloud(background_color="white", max_words=2000, mask=onion_coloring,
               stopwords=stopwords, max_font_size=40, margin=10, random_state=42)
# generate word cloud
wc.generate(text)

# %%
# show
plt.imshow(wc)
plt.axis("off")
plt.figure()

# %%
plt.imshow(wc.recolor(color_func=image_colors))
plt.axis("off")
plt.imshow(wc)
plt.axis("off")
plt.figure()

# %%
# try onion coloring
onion_coloring = np.array(Image.open("theonion_logo_inverted.png"))
image_colors = ImageColorGenerator(onion_coloring)
wc = WordCloud(background_color="white", max_words=500, mask=onion_coloring,
               stopwords=STOPWORDS, margin=10, max_font_size=40, random_state=1).generate(text)

plt.imshow(wc)
plt.axis('off')
plt.figure()

# %%
wc.recolor(color_func=grey_color_func, random_state=3)

# %%
wc.recolor(color_func=green_color_func, random_state=3)

# %%
plt.imshow(wc)
plt.axis('off')
plt.figure()

# %%
#obama face
obama_coloring = np.array(Image.open("obama_portrait4.png"))
stopwords = set(STOPWORDS)
stopwords.add("x80")
stopwords.add("xe2")

# %%
wc = WordCloud(background_color="white", max_words=2000, mask=obama_coloring,
               stopwords=stopwords, max_font_size=30, margin=10, random_state=42)
# generate word cloud
wc.generate(text)

# %%
plt.imshow(wc)
plt.axis('off')
plt.figure()

# %%
wc.recolor(color_func=grey_color_func, random_state=3)

# %%
plt.imshow(wc)
plt.axis('off')
plt.figure()
