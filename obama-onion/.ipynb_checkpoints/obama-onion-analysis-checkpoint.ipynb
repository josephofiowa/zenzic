# %% [markdown]
# # Obama & The Onion: An Analysis
#
# This notebook contains analysis of every story The Onion wrote about Obama during his presidency, as determined by their  [_Black Man Does 8 Years_](https://www.theonion.com/interactive/obama) feature.

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from textblob import TextBlob, Word
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn import svm, metrics
from sklearn.metrics import confusion_matrix
from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import cross_val_score
# plot inline
# %matplotlib inline

# %%
# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
# always be stylish
plt.style.use('ggplot')

# %% [markdown]
# ## Rudimentary EDA

# %%
# load data
obama = pd.read_csv('obama_scraped.csv')

# %%
obama.head()
# Out:
#    Unnamed: 0                                               link  \
# 0           0  http://theonion.com/article/black-guy-asks-nat...
# 1           1  http://theonion.com/article/obama-clinton-mcca...
# 2           2  http://theonion.com/article/obama-practices-lo...
# 3           3  http://theonion.com/article/time-publishes-def...
# 4           4  http://theonion.com/article/obamas-hillbilly-h...
#
#                                                title             date  \
# 0                 Black Guy Asks Nation For Change\n   March 19, 2008
# 1  Obama, Clinton, McCain Join Forces To Form Nig...     May 21, 2008
# 2     Obama Practices Looking-Off-Into-Future Pose\n     May 28, 2008
# 3     'Time' Publishes Definitive Obama Puff Piece\n    July 18, 2008
# 4  Obama's Hillbilly Half-Brother Threatening To ...  August 13, 2008
#
#        tag0                     tag1             tag2         tag3  \
# 0  Politics              Politicians       Presidents    Campaigns
# 1  Politics  War For The White House  Hillary Clinton  John Mccain
# 2  Politics  War For The White House     Barack Obama          NaN
# 3  Politics  War For The White House     Barack Obama          NaN
# 4  Politics                   Family       Presidents        Rural
#
#                       tag4                                               body
# 0                      NaN  [CHICAGO—According to witnesses, a loud black ...
# 1             Barack Obama  [WASHINGTON—Presidential hopefuls John McCain ...
# 2                      NaN  [CHICAGO—As the 2008 presidential election dra...
# 3                      NaN  [NEW YORK—Hailed by media critics as the fluff...
# 4  War For The White House  [BOONEVILLE, KY—Barack Obama's once-commanding...

# %%
# drop pesky unnamed column
obama.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# set date columns to datetime object
obama['date'] = pd.to_datetime(obama['date'])

# %%
# check unique story content tags
pd.concat([obama['tag0'], obama['tag1'], obama['tag2'], obama['tag3'], obama['tag4']]).unique()
# Out:
# array(['Politics', 'War For The White House', 'Sports', 'Crime & Justice',
#        'Survival', 'Health', 'Jobs', 'Family', 'Economy', 'Barack Obama',
#        'Revenge', 'News', 'Politicians', 'Opinion', 'Our Annual Year 2012',
#        nan, 'Animals', 'Science & Technology', 'Business', 'Violence',
#        'World', 'Entertainment', 'Death', 'Environment',
#        'Self-Improvement', 'Time Travel', 'Ecstasy Of Defeat', 'Comics',
#        'Elections', 'John Mccain', 'Disasters', 'Senior Citizens', 'War',
#        'Healthcare', 'Basketball', 'Natural Disasters',
#        'Our Annual Year 2011', 'Gay & Lesbian', 'Presidents',
#        'Unsponsored', 'College Basketball', 'Iran', 'Human Interest',
#        'Our Annual Year 2013', 'Football', 'Sex', 'Government', 'Fitness',
#        'Terrorism', 'Police', 'Education', 'Guns', 'College',
#        'World Leaders', 'Supreme Court', 'Movies', 'Pets',
#        'Hillary Clinton', 'Voting', 'Electronics', 'Tom Vilsack',
#        'Yu Wan Mei', 'Military', 'Music', 'Ifc', 'Mitt Romney',
#        'Foreign Policy', 'Video Games', 'Transportation', 'Lifestyle',
#        'Our Annual Year 2014', 'Middle East', 'Energy', 'Money',
#        'Baseball', 'Congress', 'Election 2016', 'Campaigns', 'Rural',
#        'Sports Year In Review 2010', 'Syria', 'Breaking', 'Social Media',
#        'National Security', 'Kids', 'Finance', 'Dogs', 'Recession',
#        'Editorial', 'Isis'], dtype=object)

# %%
# how many of each content tag?
pd.concat([obama['tag0'], obama['tag1'], obama['tag2'], obama['tag3'], obama['tag4']]).value_counts()
# Out:
# Politics                   190
# Barack Obama               189
# Politicians                108
# News                        45
# War For The White House     29
# Government                  11
# Our Annual Year 2012        10
# Opinion                      9
# War                          8
# Our Annual Year 2013         8
# Healthcare                   7
# Presidents                   7
# Our Annual Year 2011         7
# World Leaders                7
# World                        6
# Economy                      5
# Sports                       5
# Violence                     4
# Guns                         4
# Family                       4
# Syria                        4
# Health                       3
# Isis                         3
# Hillary Clinton              3
# Foreign Policy               3
# Lifestyle                    3
# Military                     3
# Terrorism                    3
# Unsponsored                  2
# Mitt Romney                  2
#                           ...
# Supreme Court                1
# Human Interest               1
# Football                     1
# College                      1
# Yu Wan Mei                   1
# Editorial                    1
# Finance                      1
# Energy                       1
# Money                        1
# Electronics                  1
# Movies                       1
# Time Travel                  1
# Fitness                      1
# Campaigns                    1
# Iran                         1
# Revenge                      1
# Video Games                  1
# Survival                     1
# Police                       1
# Social Media                 1
# Dogs                         1
# Ecstasy Of Defeat            1
# Self-Improvement             1
# Rural                        1
# Entertainment                1
# Disasters                    1
# Education                    1
# Transportation               1
# Voting                       1
# Death                        1
# dtype: int64

# %%
# top 10 most common story content tags
pd.concat([obama['tag0'], obama['tag1'], obama['tag2'], obama['tag3'], obama['tag4']]).value_counts().nlargest(10).plot(kind='bar', title='Top 10 Obama Article Content Tags', color='dodgerblue')
# plt.xlabel('Content Tag')
plt.ylabel('Frequency')

# %% [markdown]
# ## Time Series

# %%
# plot stories over time
ts = obama.set_index('date')

# %%
# columns?
obama.columns
# Out:
# Index([u'link', u'title', u'date', u'tag0', u'tag1', u'tag2', u'tag3', u'tag4',
#        u'body'],
#       dtype='object')

# %%
ts['Total'] = obama.index+1

# %%
# plot it
ts.plot(color='dodgerblue')
plt.xlabel('Time')
plt.ylabel('Stories')

# %%
# plot story length over time
def get_length(text):
    return len(text)

# %%
ts['length'] = ts.body.apply(get_length)

# %%
ts.plot(x=ts.index, y='length', color='dodgerblue')
plt.xlabel('Time')
plt.ylabel('Stories')

# %%
# let's plot a rolling mean instead; the above is too noisey
fig = plt.figure(figsize=(8, 6))
plt.plot(ts.length.rolling(window=10,center=False).mean(), label='Rolling Mean, 10 Stories', color='dodgerblue')
plt.legend(loc='best')
plt.title('Story Length Over Time')
plt.ylabel('Story Length')
plt.xlabel('Time')
plt.show()

# %%
# 2013-11-11  Folks, We Don't Usually Do This On The White H...      Politics
# 2013-11-12      Obama Has That Sex Dream About Nation Again\n      Politics
# 2013-11-19  Terrified Obama Trapped Inside Healthcare.gov ...          News
# 2013-11-20  White House Announces Sasha Obama To Now Be Pl...      Politics
#
#                     tag1            tag2                  tag3  \
# date
# 2013-06-05   Politicians    Barack Obama  Our Annual Year 2013
# 2013-06-06   Politicians    Barack Obama                   NaN
# 2013-06-17       Animals     Politicians  Our Annual Year 2013
# 2013-06-18       Opinion             NaN                   NaN
# 2013-07-15   Politicians    Barack Obama                   NaN
# 2013-07-19   Politicians    Barack Obama  Our Annual Year 2013
# 2013-08-07      Politics  Transportation          Barack Obama
# 2013-08-20   Politicians    Barack Obama                   NaN
# 2013-08-20  Barack Obama             NaN                   NaN
# 2013-08-22   Politicians    Barack Obama                   NaN
# 2013-08-27   Politicians    Barack Obama                 Syria
# 2013-08-30   Politicians    Barack Obama                 Syria
# 2013-09-03   Politicians    Barack Obama                 Syria
# 2013-09-18   Politicians    Barack Obama                   NaN
# 2013-09-26   Politicians      Healthcare                   NaN
# 2013-10-04   Politicians             NaN                   NaN
# 2013-10-07   Politicians             NaN                   NaN
# 2013-10-09           Sex       Lifestyle                   NaN
# 2013-10-10    Government      Healthcare                   NaN
# 2013-10-16  Barack Obama       Lifestyle                   NaN
# 2013-11-11  Barack Obama         Opinion                   NaN
# 2013-11-12   Politicians             Sex          Barack Obama
# 2013-11-19   Politicians    Barack Obama                   NaN
# 2013-11-20        Family     Politicians          Barack Obama
#
#                             tag4  \
# date
# 2013-06-05                   NaN
# 2013-06-06                   NaN
# 2013-06-17                   NaN
# 2013-06-18                   NaN
# 2013-07-15                   NaN
# 2013-07-19              Breaking
# 2013-08-07  Our Annual Year 2013
# 2013-08-20                   NaN
# 2013-08-20                   NaN
# 2013-08-22                   NaN
# 2013-08-27                   NaN
# 2013-08-30                   NaN
# 2013-09-03                   NaN
# 2013-09-18                   NaN
# 2013-09-26                   NaN
# 2013-10-04                   NaN
# 2013-10-07                   NaN
# 2013-10-09                   NaN
# 2013-10-10                   NaN
# 2013-10-16                   NaN
# 2013-11-11                   NaN
# 2013-11-12                   NaN
# 2013-11-19                   NaN
# 2013-11-20                   NaN
#
#                                                          body  Total  length
# date
# 2013-06-05  [WANA, PAKISTAN—Calling it a chance to get som...    166     922
# 2013-06-06  [WASHINGTON—On the heels of reports that the N...    167    1188
# 2013-06-17  [WASHINGTON—Spectators outside the White House...    168     977
# 2013-06-18  [Leading the greatest country in the world is ...    169    4927
# 2013-07-15  [WASHINGTON—Saying that she had put it off for...    170     916
# 2013-07-19  [WASHINGTON—Robert Linder, a miniature man who...    171    4721
# 2013-08-07  [WASHINGTON—Sighing and shaking his head, a sh...    172    4190
# 2013-08-20  [WASHINGTON—Carefully jotting down notes as th...    173    4812
# 2013-08-20  [WASHINGTON—Providing a friendly playmate for ...    174     951
# 2013-08-22  [WASHINGTON—Assuring the nation that he was “c...    175    1266
# 2013-08-27  [WASHINGTON—Facing mounting domestic and inter...    176    1333
# 2013-08-30  [WASHINGTON—During a meeting with Cabinet-leve...    177    1237
# 2013-09-03  [WASHINGTON—As fierce debate continued this we...    178    4243
# 2013-09-18  [WASHINGTON—With the nation still reeling from...    179    4166
# 2013-09-26  [SEATTLE—As debate continues in Washington ove...    180    4792
# 2013-10-04  [WASHINGTON—As the federal government shutdown...    181    3020
# 2013-10-07  [WASHINGTON—Stating that he had been informed ...    182    4323
# 2013-10-09  [WASHINGTON—Sitting down for a candid intervie...    183    5232
# 2013-10-10  [WASHINGTON—Following this month’s rollout of ...    184    1246
# 2013-10-16  [WASHINGTON—Addressing the nation from a candl...    185    4922
# 2013-11-11  [And so that’s the Vermeil Room, ladies and ge...    186    4075
# 2013-11-12  [WASHINGTON—After awaking from a restless slee...    187    4651
# 2013-11-19  [WASHINGTON—According to an urgent report issu...    188    3638
# 2013-11-20  [WASHINGTON—In a move that has caused a nation...    189     955

# %% [markdown]
# ## Text Processing

# %%
# grab only text
text = obama.body

# %%
# check it out
print(text[0:5])
# Out:
# 0    [CHICAGO—According to witnesses, a loud black ...
# 1    [WASHINGTON—Presidential hopefuls John McCain ...
# 2    [CHICAGO—As the 2008 presidential election dra...
# 3    [NEW YORK—Hailed by media critics as the fluff...
# 4    [BOONEVILLE, KY—Barack Obama's once-commanding...
# Name: body, dtype: object

# %%
# create function to grab location
def get_location(text):
    location, sep, body = text.partition('—')
    if len(location) > 100:
        return np.nan
    else:
        return location[1:]

# %%
# create location column
obama['location'] = obama.body.apply(get_location)

# %%
# create function to get body text without location
def get_body(text):
    if '—' in text[0:50]:
        location, sep, body = text.partition('—')
        if len(location) > 100:
            pass
        else:
            return body
    else:
        return text

# %%
# replace old body with new location-less body
obama['body'] = obama.body.apply(get_body)

# %%
# examine new df
obama.head(20)
# Out:
#                                                  link  \
# 0   http://theonion.com/article/black-guy-asks-nat...
# 1   http://theonion.com/article/obama-clinton-mcca...
# 2   http://theonion.com/article/obama-practices-lo...
# 3   http://theonion.com/article/time-publishes-def...
# 4   http://theonion.com/article/obamas-hillbilly-h...
# 5   http://theonion.com/article/obama-modifies-yes...
# 6   http://theonion.com/article/obama-suddenly-pan...
# 7   http://theonion.com/article/obama-deletes-anot...
# 8   http://theonion.com/article/parents-of-obama-v...
# 9   http://theonion.com/article/obama-clinches-joe...
# 10  http://theonion.com/article/obama-under-fire-f...
# 11  http://theonion.com/article/southern-sheriff-p...
# 12  http://theonion.com/article/i-would-make-a-bad...
# 13  http://theonion.com/article/as-election-draws-...
# 14  http://theonion.com/article/obama-warns-he-may...
# 15  http://theonion.com/article/obamas-record-brea...
# 16  http://theonion.com/article/black-man-given-na...
# 17  http://theonion.com/article/hillary-clinton-re...
# 18  http://theonion.com/article/nation-finally-shi...
# 19  http://theonion.com/article/kobe-bryant-scores...
#
#                                                 title       date  \
# 0                  Black Guy Asks Nation For Change\n 2008-03-19
# 1   Obama, Clinton, McCain Join Forces To Form Nig... 2008-05-21
# 6   Sen. Barack Obama (D-IL) fell deathly silent i...      MADISON, WI
# 7   After receiving yet another unwanted e-mail fr...          CHICAGO
# 8   Parents of Obama '08 campaign volunteer Mark L...     OAK PARK, IL
# 9   Following a strong performance by the Democrat...       WASHINGTON
# 10  At a press conference on Monday, members of th...       WASHINGTON
# 11  Despite obeying the posted speed limit and hav...     FOXWORTH, MS
# 12  In a campaign gaffe that could potentially jeo...  TALLAHASSEE, FL
# 13  After hearing the Democratic nominee call on h...      BURBANK, CA
# 14  Unless citizens throughout America keep him in...     INDIANAPOLIS
# 15  After taking in more than $150 million in Sept...       WASHINGTON
# 16  African-American man Barack Obama, 47, was giv...       WASHINGTON
# 17  Less than 20 minutes after Barack Obama was el...         NEW YORK
# 18  After emerging victorious from one of the most...       WASHINGTON
# 19  Lakers shooting guard Kobe Bryant had a typica...      LOS ANGELES

# %%
# not bad, Mr Location Function.
obama.isnull().sum()
# Out:
# link          0
# title         0
# date          0
# tag0          2
# tag1         28
# tag2         95
# tag3        186
# tag4        231
# body          0
# location     11
# dtype: int64

# %%
# list all locations
obama.location.unique()
# Out:
# array(['CHICAGO', 'WASHINGTON', 'NEW YORK', 'BOONEVILLE, KY',
#        'COLUMBIA, SC', 'MADISON, WI', 'OAK PARK, IL', 'FOXWORTH, MS',
#        'TALLAHASSEE, FL', 'BURBANK, CA', 'INDIANAPOLIS', 'LOS ANGELES',
#        'HUTCHINSON, KS', 'ATHENS, GA', 'VAVUNIYA, SRI LANKA', 'PHOENIX',
#        ']', nan, 'KABUL, AFGHANISTAN', 'MIAMI', 'ROCKLAND, ME',
#        'NEW ORLEANS', 'CAMP SPRINGS, MD', 'HARTFORD, CT', 'KALONA, IA',
#        'GRAND RAPIDS, MI', 'CINCINNATI', 'PITTSBURGH', 'HENNIKER, NH',
#        'WEST LEBANON, NH', 'NEW BRITAIN, CT', 'COVINGTON, KY',
#        'CHARLOTTE, NC', 'CHARLESTON, WV', 'COLUMBUS, OH',
#        'EVERYWHERE IN SPACE-TIME SIMULTANEOUSLY', 'DENVER',
#        'HEMPSTEAD, NY', 'PARMA, OH', 'BOCA RATON, FL', 'WOOFINGTON, D.C.',
#        'TEL AVIV, ISRAEL', 'JERUSALEM', 'DALLAS', 'CORTLAND, NY',
#        'WANA, PAKISTAN', 'SEATTLE', 'WALTHAM, MA', 'SEDALIA, MO', 'HAVANA',
#        'BAY LAKE, FL', 'PHILADELPHIA', 'THURMONT, MD', 'GARDINER, MT',
#        'CEDAR PLAINS, PA'], dtype=object)

# %%
# identify top locations
obama.location.value_counts()
# Out:
# WASHINGTON                                 182
# CHICAGO                                      7
# JERUSALEM                                    3
# NEW YORK                                     3
# BOCA RATON, FL                               2
# PHILADELPHIA                                 2
# COLUMBIA, SC                                 2
# CHARLOTTE, NC                                2
# DENVER                                       2
# ]                                            2
# ROCKLAND, ME                                 1
# BURBANK, CA                                  1
# CORTLAND, NY                                 1
# LOS ANGELES                                  1
# KALONA, IA                                   1
# WOOFINGTON, D.C.                             1
# CHARLESTON, WV                               1
# OAK PARK, IL                                 1
# EVERYWHERE IN SPACE-TIME SIMULTANEOUSLY      1
# WANA, PAKISTAN                               1
# BAY LAKE, FL                                 1
# ATHENS, GA                                   1
# CEDAR PLAINS, PA                             1
# WEST LEBANON, NH                             1
# HARTFORD, CT                                 1
# PITTSBURGH                                   1
# MADISON, WI                                  1
# CINCINNATI                                   1
# NEW BRITAIN, CT                              1
# THURMONT, MD                                 1
# COVINGTON, KY                                1
# CAMP SPRINGS, MD                             1
# GRAND RAPIDS, MI                             1
# SEATTLE                                      1
# HENNIKER, NH                                 1
# NEW ORLEANS                                  1
# PARMA, OH                                    1
# TALLAHASSEE, FL                              1
# PHOENIX                                      1
# FOXWORTH, MS                                 1
# DALLAS                                       1
# HAVANA                                       1
# KABUL, AFGHANISTAN                           1
# VAVUNIYA, SRI LANKA                          1
# GARDINER, MT                                 1
# HEMPSTEAD, NY                                1
# HUTCHINSON, KS                               1
# WALTHAM, MA                                  1
# BOONEVILLE, KY                               1
# MIAMI                                        1
# COLUMBUS, OH                                 1
# INDIANAPOLIS                                 1
# TEL AVIV, ISRAEL                             1
# SEDALIA, MO                                  1
# Name: location, dtype: int64

# %% [markdown]
# Locations follow relatively what we'd expect: overwhelmingly in DC, some missing values, and in Chicago's hometown.
#
# Let's check out some of the bizarre locations...

# %%
# space?
obama[obama.location=='EVERYWHERE IN SPACE-TIME SIMULTANEOUSLY']
# Out:
#                                                   link  \
# 119  http://theonion.com/article/obama-makes-surpri...
#
#                                                  title       date      tag0  \
# 119  Obama Makes Surprise Visit To Quantum-Branchin... 2012-10-02  Politics
#
#             tag1          tag2 tag3 tag4  \
# 119  Politicians  Barack Obama  NaN  NaN
#
#                                                   body  \
# 119  Attempting to appeal to the widest possible de...
#
#                                     location
# 119  EVERYWHERE IN SPACE-TIME SIMULTANEOUSLY

# %% [markdown]
# <img src="story-screenshots/obama-quantum.png">
#
# [source](http://www.theonion.com/article/obama-makes-surprise-visit-to-quantum-branching-mu-29763)

# %%
# Pakistan?
obama[obama.location=='WANA, PAKISTAN']
# Out:
#                                                   link  \
# 165  http://theonion.com/article/obama-takes-excite...
#
#                                                  title       date  tag0  \
# 165  Obama Takes Excited Daughters Out For Day Of D... 2013-06-05  News
#
#             tag1          tag2                  tag3 tag4  \
# 165  Politicians  Barack Obama  Our Annual Year 2013  NaN
#
#                                                   body        location
# 165  Calling it a chance to get some fresh air and ...  WANA, PAKISTAN

# %% [markdown]
# <img src="story-screenshots/obama-pakistan.png">
#
# [source](http://www.theonion.com/article/obama-takes-excited-daughters-out-for-day-of-drone-32702)

# %%
# like I was going to check Iowa
obama[obama.location=='KALONA, IA']
# Out:
#                                                  link  \
# 82  http://theonion.com/article/obamas-aunt-sends-...
#
#                                                 title       date    tag0 tag1  \
# 82  Obama's Aunt Sends Him Article Mentioning Unit... 2011-06-16  Family  NaN
#
#    tag2 tag3 tag4                                               body  \
# 82  NaN  NaN  NaN  According to family sources, Barack Obama's au...
#
#       location
# 82  KALONA, IA

# %% [markdown]
# <img src="story-screenshots/obama-iowa.png">
#
# [source](http://www.theonion.com/article/obamas-aunt-sends-him-article-mentioning-united-st-20734)

# %%
# The Onion like to hit Obama on (a lack of) Israel visits...
obama[obama.location=='JERUSALEM']
# Out:
#                                                   link  \
# 147  http://theonion.com/article/obama-sarcasticall...
# 148  http://theonion.com/article/obama-rachel-golds...
# 149  http://theonion.com/article/palestinians-israe...
#
#                                                  title       date      tag0  \
# 147  Obama Sarcastically Asks How Israel Afforded S... 2013-03-20  Politics
# 148  Obama, Rachel Goldstein Really Hitting It Off ... 2013-03-21  Politics
# 149  Palestinians, Israelis Come Together To Mock O... 2013-03-21  Politics
#
#             tag1            tag2          tag3 tag4  \
# 147  Politicians  Foreign Policy  Barack Obama  NaN
# 148  Politicians             NaN           NaN  NaN
# 149        World   World Leaders           NaN  NaN
#
#                                                   body   location
# 147  While touring Israel’s “Iron Dome” all-weather...  JERUSALEM
# 148  Participants on Taglit Shorashim’s Israel Expe...  JERUSALEM
# 149  Coming together for the first time in generati...  JERUSALEM

# %% [markdown]
# I screenshotted the third story.
# <img src="story-screenshots/obama-jerusalem3.png">
#
# [source](http://www.theonion.com/article/palestinians-israelis-come-together-to-mock-obamas-31767)
#
# First Jerusalem story [here](http://www.theonion.com/article/obama-sarcastically-asks-how-israel-afforded-such--31750) and second Jerusalem story [here](http://www.theonion.com/article/obama-rachel-goldstein-really-hitting-it-off-on-gr-31753)

# %%
# Afghanistan
obama[obama.location=='KABUL, AFGHANISTAN']
# Out:
#                                                  link  \
# 50  http://theonion.com/article/us-continues-quagm...
#
#                                                 title       date      tag0  \
# 50  U.S. Continues Quagmire-Building Effort In Afg... 2009-10-27  Politics
#
#    tag1      tag2 tag3 tag4  \
# 50  War  Military  NaN  NaN
#
#                                                  body            location
# 50   According to sources at the Pentagon, America...  KABUL, AFGHANISTAN

# %% [markdown]
# <img src="story-screenshots/obama-afghanistan.png">
#
# [source](http://www.theonion.com/article/us-continues-quagmire-building-effort-in-afghanist-2837)

# %%
obama.head()
# Out:
#                                                 link  \
# 0  http://theonion.com/article/black-guy-asks-nat...
# 1  http://theonion.com/article/obama-clinton-mcca...
# 2  http://theonion.com/article/obama-practices-lo...
# 3  http://theonion.com/article/time-publishes-def...
# 4  http://theonion.com/article/obamas-hillbilly-h...
#
#                                                title       date      tag0  \
# 0                 Black Guy Asks Nation For Change\n 2008-03-19  Politics
# 1  Obama, Clinton, McCain Join Forces To Form Nig... 2008-05-21  Politics
# 2     Obama Practices Looking-Off-Into-Future Pose\n 2008-05-28  Politics
# 3     'Time' Publishes Definitive Obama Puff Piece\n 2008-07-18  Politics
# 4  Obama's Hillbilly Half-Brother Threatening To ... 2008-08-13  Politics
#
#                       tag1             tag2         tag3  \
# 0              Politicians       Presidents    Campaigns
# 1  War For The White House  Hillary Clinton  John Mccain
# 2  War For The White House     Barack Obama          NaN
.decode('utf-8')): ord("'"),
            ord('\xe2\x80\x9c'.decode('utf-8')): ord('"'),
            ord('\xe2\x80\x9d'.decode('utf-8')): ord('"'),
            ord('\xe2\x80\x9e'.decode('utf-8')): ord('"'),
            ord('\xe2\x80\x9f'.decode('utf-8')): ord('"'),
            ord('\xc3\xa9'.decode('utf-8')): ord('e'),
            ord('\xe2\x80\x9c'.decode('utf-8')): ord('"'),
            ord('\xe2\x80\x93'.decode('utf-8')): ord('-'),
            ord('\xe2\x80\x92'.decode('utf-8')): ord('-'),
            ord('\xe2\x80\x94'.decode('utf-8')): ord('-'),
            ord('\xe2\x80\x94'.decode('utf-8')): ord('-'),
            ord('\xe2\x80\x98'.decode('utf-8')): ord("'"),
            ord('\xe2\x80\x9b'.decode('utf-8')): ord("'"),

            ord('\xe2\x80\x90'.decode('utf-8')): ord('-'),
            ord('\xe2\x80\x91'.decode('utf-8')): ord('-'),

            ord('\xe2\x80\xb2'.decode('utf-8')): ord("'"),
            ord('\xe2\x80\xb3'.decode('utf-8')): ord("'"),
            ord('\xe2\x80\xb4'.decode('utf-8')): ord("'"),
            ord('\xe2\x80\xb5'.decode('utf-8')): ord("'"),
            ord('\xe2\x80\xb6'.decode('utf-8')): ord("'"),
            ord('\xe2\x80\xb7'.decode('utf-8')): ord("'"),

            ord('\xe2\x81\xba'.decode('utf-8')): ord("+"),
            ord('\xe2\x81\xbb'.decode('utf-8')): ord("-"),
            ord('\xe2\x81\xbc'.decode('utf-8')): ord("="),
            ord('\xe2\x81\xbd'.decode('utf-8')): ord("("),
            ord('\xe2\x81\xbe'.decode('utf-8')): ord(")"),

                            }
    try:
        return text.decode('utf-8').translate(uni2ascii).encode('ascii')
    except:
        return text

# %%
# check it
print(unicodetoascii(text[0]))
# Out:
# According to witnesses, a loud black man approached a crowd of some 4,000 strangers in downtown Chicago Tuesday and made repeated demands for change., "The time for change is now," said the black guy, yelling at everyone within earshot for 20 straight minutes, practically begging America for change. "The need for change is stronger and more urgent than ever before. And only you-the people standing here today, and indeed all the people of this great nation-only you can deliver this change.", It is estimated that, to date, the black man has asked every single person in the United States for change., "I've already seen this guy four times today," Chicago-area ad salesman Blake Gordon said. "Every time, it's the same exact spiel. 'I need change.' 'I want change.' Why's he so eager for all this change? What's he going to do with it, anyway?", After his initial requests for change, the black man rambled nonstop on a variety of unrelated topics, calling for affordable health care, demanding that the government immediately begin withdrawing troops from Iraq, and proposing a $75 billion economic stimulus plan to create new jobs., "What a wacko," Schaumburg, IL resident Patrick Morledge said. "And, of course, after telling us all about how he had the ability to magically fix everything, he went right back to asking for change. Typical.", "If he's really looking for change, he's got the wrong guy," Morledge added., Reports indicate that the black man has been riding from city to city across the country, asking for change wherever he goes. Citizens in Austin, TX said they spotted the same guy standing on the street Friday, shouting far-fetched ideas about global warming. Cleveland residents also reported seeing him in a local park, wildly gesticulating and quoting from the Bible. And last week, patrons at the Starlight Diner in Cheyenne, WY claimed that the black man accosted them while they were eating, repeatedly requesting change., "I saw him walk in and I knew he was headed straight for our table," said mother of three Gladys Davies. "He just stood there smiling at us for a while, and asked how our food tasted. Then he went and did the same thing at the next table over. The nerve of some people.", Those who encountered the black man Tuesday said he engaged in erratic behavior, including pointing at random people in the crowd and desperately saying he needs their help, going up to complete strangers and hugging them, and angrily claiming that he is not looking for just a little bit of change, but rather a great deal of change, and that he wants it "right now.", "I'll be honest, when that black guy said he would 'stop at nothing' to get change, it kind of scared me," local mechanic Phil Nighbert said. "Just leave me alone.", Though many were taken aback by the black man's brazen demands, some, such as Jackson, MS's Holly Moser, sympathized with him. She gave the black man credit for boldly standing up and asking every last person around him for change. , "I told him I'd give him some if I saw him later, even though I probably won't," Moser said. "Very nice man, though.", Most, however, ignored his requests. , "I'm a hardworking American who pays his taxes, and the last thing I need is some guy on the street demanding change from me," said William Overkamp, a Springfield, IL gun-shop owner., He added, "What he really needs is a job." ]

# %%
# apply the above to the whole dataframe
obama['body'] = obama.body.apply(unicodetoascii)

# %%
# export cleaner file to csv as clean file
obama.to_csv('obama_cleaned.csv')

# %% [markdown]
# ## Text Analysis

# %%
# obama = pd.read_csv('obama_cleaned.csv')
text = obama.body

# %%
text[0:5]
# Out:
# 0    According to witnesses, a loud black man appro...
# 1    Presidential hopefuls John McCain (R-AZ), Bara...
# 2    As the 2008 presidential election draws closer...
# 3    Hailed by media critics as the fluffiest, most...
# 4    Barack Obama's once-commanding lead in the pol...
# Name: body, dtype: object

# %%
'''
create a document term matrix with:
-ngram range 1,2
-minimum document appearance for any term = 2
-removal of all English stop words
'''
vect = CountVectorizer(ngram_range=(1, 2), stop_words='english', min_df=2)
dtm = vect.fit_transform(text)

# %%
# do the above, but make a dataframe with feature names = words
tf = pd.DataFrame(vect.fit_transform(text).toarray(), columns=vect.get_feature_names())

# %%
# see most common terms
tf.sum().sort_values(ascending=False)
# Out:
# obama                     1248
# president                  824
# said                       652
# just                       301
# house                      277
# time                       274
# white                      259
# white house                232
# barack                     214
# nation                     184
# people                     184
# like                       184
# added                      178
# barack obama               174
# sources                    161
# reportedly                 159
# american                   151
# americans                  147
# know                       135
# press                      132
# years                      132
# president obama            129
# according                  127
# right                      124
# country                    123
# new                        123
# confirmed                  121
# office                     120
# year                       112
# really                     112
#                           ...
# president finally            2
# president franklin           2
# president genuinely          2
# president according          2
# president 2008               2
# preserving environment       2
# exploit                      2
# precious                     2
# precipitously                2
# extension                    2
# precision                    2
# expressed concern            2
# predict                      2
# explosion                    2
# exploring                    2
# exploration                  2
# exploiting                   2
# exploding                    2
# experimentation              2
# explicit                     2
# preparing                    2
# presented president          2
# explained obama              2
# explained nation             2
# presents                     2
# preservation                 2
# experts said                 2
# experts agree                2
# preserved                    2
# zone                         2
# dtype: int64

# %% [markdown]
# Let's compare Obama's first and second term.

# %%
# create first term df
obama_first = obama[obama.date < '2013-01-20']

# %%
# 134 stories
obama_first.shape
# Out:
# (134, 10)

# %%
# create second term df
obama_second = obama[obama.date >= '2013-01-20']

# %%
# 128 story - remarkably equitable classes
obama_second.shape
# Out:
# (128, 10)

# %%
# vectorize terms from first term
tf1 = pd.DataFrame(vect.fit_transform(obama_first.body).toarray(), columns=vect.get_feature_names())

# %%
# check value counts
tf1.sum().sort_values(ascending=False)
# Out:
# obama                    784
# president                443
# said                     400
# just                     155
# time                     141
# barack                   137
# house                    129
# white                    125
# people                   118
# barack obama             116
# like                     113
# white house              105
# nation                   104
# american                  99
# americans                 98
# added                     96
# new                       92
# campaign                  89
# years                     85
# according                 79
# man                       77
# country                   77
# year                      72
# know                      72
# sources                   71
# reportedly                68
# obama said                68
# states                    68
# romney                    66
# right                     64
#                         ...
# real leadership            2
# earn                       2
# really time                2
# red white                  2
# recovery president         2
# recovery plan              2
# mississippi                2
# recent history             2
# eat                        2
# jaw                        2
# echo                       2
# reasonable                 2
# economic crisis            2
# economic recession         2
# really want                2
# economic turmoil           2
# effort counter             2
# really set                 2
# economy obama              2
# really really              2
# really needs               2
# editorials                 2
# really loud                2
# mistakes                   2
# really did                 2
# effective immediately      2
# effectively                2
# jan 20                     2
# realistic                  2
# rolled                     2
# dtype: int64

# %%
# check terms for term two
tf2 = pd.DataFrame(vect.fit_transform(obama_second.body).toarray(), columns=vect.get_feature_names())

# %%
# check totals
tf2.sum().sort_values(ascending=False)
# Out:
# obama                     464
# president                 381
# said                      252
# house                     148
# just                      146
# white                     134
# time                      133
# white house               127
# reportedly                 91
# sources                    90
# added                      82
# confirmed                  81
# nation                     80
# barack                     77
# press                      73
# like                       71
# president obama            71
# people                     66
# ll                         63
# know                       63
# right                      60
# office                     60
# barack obama               58
# old                        52
# american                   52
# day                        52
# ve                         50
# going                      50
# way                        49
# really                     49
#                          ...
# fat                         2
# obama term                  2
# fathers                     2
# factions                    2
# twin                        2
# occur                       2
# official white              2
# experimental                2
# ol                          2
# okay sure                   2
# stunning                    2
# oil spill                   2
# ohio                        2
# oh god                      2
# officials said              2
# officials announced         2
# officially                  2
# extracting                  2
# oct                         2
# office sources              2
# eye contact                 2
# office east                 2
# submit                      2
# eyewitnesses                2
# eyewitnesses confirmed      2
# type                        2
# face face                   2
# offers                      2
# faces                       2
# situation room              2
# dtype: int64

# %%
# word counts of first and second term
word_counts = pd.merge(pd.DataFrame(data=tf1.sum().sort_values(ascending=False)),pd.DataFrame(data=tf2.sum().sort_values(ascending=False)),how='outer',left_index=True,right_index=True)
print(word_counts)
# Out:
#                     0_x   0_y
# 00                  3.0   NaN
# 000                37.0  19.0
# 000 citizens        2.0   NaN
# 000 person          2.0   NaN
# 000 soldiers        2.0   2.0
# 000 square          NaN   2.0
# 000 supporters      3.0   NaN
# 000 votes           2.0   NaN
# 10                 30.0  13.0
# 10 000              3.0   NaN
# 10 15               3.0   NaN
# 10 minutes          NaN   2.0
# 10 percent          2.0   NaN
# 10 years            5.0   NaN
# 100                 8.0   8.0
# 100 days            2.0   2.0
# 11                  9.0   5.0
# 11 year             3.0   NaN
# 12                 16.0   7.0
# 12 points           2.0   NaN
# 12 times            2.0   NaN
# 12 years            2.0   NaN
# 13                  3.0   3.0
# 132                 4.0   NaN
# 132 room            4.0   NaN
# 14                  5.0   2.0
# 15                 11.0   7.0
# 15 minutes          3.0   2.0
# 15 percent          2.0   NaN
# 15 years            3.0   NaN
# ...                 ...   ...
# wrong              10.0   2.0
# wrong obama         2.0   NaN
# wrote               8.0   NaN
# wrought             NaN   2.0
# yards               2.0   NaN
# yards away          2.0   NaN
# yeah                3.0   7.0
# year               72.0  40.0
# year half           2.0   NaN
# year old           34.0  21.0
# years              85.0  47.0
# years ago           6.0   4.0
# years earlier       2.0   NaN
# years obama         3.0   NaN
# years old           2.0   2.0
# years president     NaN   3.0
# yemen               NaN   3.0
# yes                21.0   8.0
# yesterday           5.0   5.0
# ymca                2.0   NaN
# york               15.0   3.0
# york city           2.0   NaN
# york times          6.0   NaN
# young              12.0   7.0
# young daughters     2.0   NaN
# younger             2.0   NaN
# youngest            5.0   NaN
# youngest daughter   3.0   NaN
# youth               2.0   NaN
# zero                5.0   NaN
#
# [6158 rows x 2 columns]

# %%
# rename columns
word_counts.columns = ['term_one', 'term_two']

# %%
# view the df
word_counts.head()
# Out:
#               term_one  term_two
# 00                 3.0       NaN
# 000               37.0      19.0
# 000 citizens       2.0       NaN
# 000 person         2.0       NaN
# 000 soldiers       2.0       2.0

# %%
# find sums
word_counts['sum'] = word_counts['term_one'] + word_counts['term_two']

# %%
# sort by most used values
word_counts.sort_values(['sum'], ascending=False)
# Out:
#                    term_one  term_two     sum
# obama                 784.0     464.0  1248.0
# president             443.0     381.0   824.0
# said                  400.0     252.0   652.0
# just                  155.0     146.0   301.0
# house                 129.0     148.0   277.0
# time                  141.0     133.0   274.0
# white                 125.0     134.0   259.0
# white house           105.0     127.0   232.0
# barack                137.0      77.0   214.0
# people                118.0      66.0   184.0
# nation                104.0      80.0   184.0
# like                  113.0      71.0   184.0
# added                  96.0      82.0   178.0
# barack obama          116.0      58.0   174.0
# sources                71.0      90.0   161.0
# reportedly             68.0      91.0   159.0
# american               99.0      52.0   151.0
# americans              98.0      49.0   147.0
# know                   72.0      63.0   135.0
# years                  85.0      47.0   132.0
# press                  59.0      73.0   132.0
# president obama        58.0      71.0   129.0
# according              79.0      48.0   127.0
# right                  64.0      60.0   124.0
# country                77.0      46.0   123.0
# new                    92.0      31.0   123.0
# confirmed              40.0      81.0   121.0
# office                 60.0      60.0   120.0
# year                   72.0      40.0   112.0
# really                 63.0      49.0   112.0
# ...                     ...       ...     ...
# worldwide               2.0       NaN     NaN
# worried                 5.0       NaN     NaN
# worry                   NaN       6.0     NaN
# worry obama             NaN       2.0     NaN
# worse                   4.0       NaN     NaN
# worship                 2.0       NaN     NaN
# worthless               NaN       2.0     NaN
# worthy                  2.0       NaN     NaN
# wow                     NaN       2.0     NaN
# wrapped                 NaN       4.0     NaN
# wrapping                NaN       2.0     NaN
# wrong obama             2.0       NaN     NaN
# wrote                   8.0       NaN     NaN
# wrought                 NaN       2.0     NaN
# yards                   2.0       NaN     NaN
# yards away              2.0       NaN     NaN
# year half               2.0       NaN     NaN
# years earlier           2.0       NaN     NaN
# years obama             3.0       NaN     NaN
# years president         NaN       3.0     NaN
# yemen                   NaN       3.0     NaN
# ymca                    2.0       NaN     NaN
# york city               2.0       NaN     NaN
# york times              6.0       NaN     NaN
# young daughters         2.0       NaN     NaN
# younger                 2.0       NaN     NaN
# youngest                5.0       NaN     NaN
# youngest daughter       3.0       NaN     NaN
# youth                   2.0       NaN     NaN
# zero                    5.0       NaN     NaN
#
# [6158 rows x 3 columns]

# %%
# optionally sort by term_one THEN term_two
# word_counts.sort_values(['term_one', 'term_two'], ascending=[False, False])

# %%
# curiousity
word_counts.transpose()
# Out:
#            00   000  000 citizens  000 person  000 soldiers  000 square  \
# term_one  3.0  37.0           2.0         2.0           2.0         NaN
# term_two  NaN  19.0           NaN         NaN           2.0         2.0
# sum       NaN  56.0           NaN         NaN           4.0         NaN
#
#           000 supporters  000 votes    10  10 000  ...   york  york city  \
# term_one             3.0        2.0  30.0     3.0  ...   15.0        2.0
# term_two             NaN        NaN  13.0     NaN  ...    3.0        NaN
# sum                  NaN        NaN  43.0     NaN  ...   18.0        NaN
#
#           york times  young  young daughters  younger  youngest  \
# term_one         6.0   12.0              2.0      2.0       5.0
# term_two         NaN    7.0              NaN      NaN       NaN
# sum              NaN   19.0              NaN      NaN       NaN
#
#           youngest daughter  youth  zero
# term_one                3.0    2.0   5.0
# term_two                NaN    NaN   NaN
# sum                     NaN    NaN   NaN
#
# [3 rows x 6158 columns]

# %%
# plot 25 most used terms
word_counts.sort_values(['sum'], ascending=False).drop('sum', axis=1).head(25).plot(kind='bar')

# %%
# make horizontal plots
def horizontal_plot(terms):
    ind = np.arange(len(word_counts.head(terms)))
    width = 0.4
    fig, ax = plt.subplots()
    
    # grab appropriate data
    term_one = word_counts.sort_values(['sum'], ascending=False).drop('sum', axis=1).head(terms).values[:,0]
    term_two = word_counts.sort_values(['sum'], ascending=False).drop('sum', axis=1).head(terms).values[:,1]
    ylabels = word_counts.sort_values(['sum'], ascending=False).drop('sum', axis=1).head(terms).index
    
    # plot it
    ax.barh(ind, term_one, width, label='First Term', color='dodgerblue')
    ax.barh(ind + width, term_two, width, color='deepskyblue', label='Second Term')
    ax.set(yticks=ind + width, yticklabels=ylabels, ylim=[2*width - 1, len(word_counts.head(terms))])
    
    # fix axis, add details
    ax.legend(loc='lower right')
    plt.title("The Onion's %d Most Used Terms During Obama's Presidency"%terms, y=1.03, fontsize=14)
    plt.xlabel("Term Count")
    plt.gca().invert_yaxis()
    plt.show()

# %%
# top 10 words
horizontal_plot(10)

# %%
# top 20 words
horizontal_plot(20)

# %% [markdown]
# ### Use TF-IDF to investigate word importances

# %%
# repeat above, but for TF-IDF instead of CVEC
tfidf1 = pd.DataFrame(vect.fit_transform(obama_first.body).toarray(), columns=vect.get_feature_names())
tfidf2 = pd.DataFrame(vect.fit_transform(obama_second.body).toarray(), columns=vect.get_feature_names())
tfidf_scores = pd.merge(pd.DataFrame(data=tfidf1.sum().sort_values(ascending=False)),pd.DataFrame(data=tfidf2.sum().sort_values(ascending=False)),how='outer',left_index=True,right_index=True)
tfidf_scores.columns = ['term_one', 'term_two']
tfidf_scores['sum'] = tfidf_scores['term_one'] + tfidf_scores['term_two']
tfidf_scores.sort_values(['sum'], ascending=False)
# Out:
#                    term_one  term_two     sum
# obama                 784.0     464.0  1248.0
# president             443.0     381.0   824.0
# said                  400.0     252.0   652.0
# just                  155.0     146.0   301.0
# house                 129.0     148.0   277.0
# time                  141.0     133.0   274.0
# white                 125.0     134.0   259.0
# white house           105.0     127.0   232.0
# barack                137.0      77.0   214.0
# people                118.0      66.0   184.0
# nation                104.0      80.0   184.0
# like                  113.0      71.0   184.0
# added                  96.0      82.0   178.0
# barack obama          116.0      58.0   174.0
# sources                71.0      90.0   161.0
# reportedly             68.0      91.0   159.0
# american               99.0      52.0   151.0
# americans              98.0      49.0   147.0
# know                   72.0      63.0   135.0
# years                  85.0      47.0   132.0
# press                  59.0      73.0   132.0
# president obama        58.0      71.0   129.0
# according              79.0      48.0   127.0
# right                  64.0      60.0   124.0
# country                77.0      46.0   123.0
# new                    92.0      31.0   123.0
# confirmed              40.0      81.0   121.0
# office                 60.0      60.0   120.0
# year                   72.0      40.0   112.0
# really                 63.0      49.0   112.0
# ...                     ...       ...     ...
# worldwide               2.0       NaN     NaN
# worried                 5.0       NaN     NaN
# worry                   NaN       6.0     NaN
# worry obama             NaN       2.0     NaN
# worse                   4.0       NaN     NaN
# worship                 2.0       NaN     NaN
# worthless               NaN       2.0     NaN
# worthy                  2.0       NaN     NaN
# wow                     NaN       2.0     NaN
# wrapped                 NaN       4.0     NaN
# wrapping                NaN       2.0     NaN
# wrong obama             2.0       NaN     NaN
# wrote                   8.0       NaN     NaN
# wrought                 NaN       2.0     NaN
# yards                   2.0       NaN     NaN
# yards away              2.0       NaN     NaN
# year half               2.0       NaN     NaN
# years earlier           2.0       NaN     NaN
# years obama             3.0       NaN     NaN
# years president         NaN       3.0     NaN
# yemen                   NaN       3.0     NaN
# ymca                    2.0       NaN     NaN
# york city               2.0       NaN     NaN
# york times              6.0       NaN     NaN
# young daughters         2.0       NaN     NaN
# younger                 2.0       NaN     NaN
# youngest                5.0       NaN     NaN
# youngest daughter       3.0       NaN     NaN
# youth                   2.0       NaN     NaN
# zero                    5.0       NaN     NaN
#
# [6158 rows x 3 columns]

# %%
# plot 25 most used terms
tfidf_scores.sort_values(['sum'], ascending=False).drop('sum', axis=1).head(25).plot(kind='bar')

# %% [markdown]
# Nothing particularly different about using TF-IDF vs traditional word counts. Not too surprising.

# %%
# create a document-term matrix on whole dataset using TF-IDF
vect = TfidfVectorizer(stop_words='english')
dtm = vect.fit_transform(obama.body)
features = vect.get_feature_names()
dtm.shape
# Out:
# (262, 12008)

# %%
# use TF-IDF to summarize any story
def summarize():
    
    # choose a random review that is at least 300 characters
    story_length = 0
    while story_length < 300:
        story_id = np.random.randint(0, len(obama))
        story_text = unicode(obama.body[story_id], 'utf-8')
        story_length = len(story_text)
    
    # create a dictionary of words and their TF-IDF scores
    word_scores = {}
    for word in TextBlob(story_text).words:
        word = word.lower()
        if word in features:
            word_scores[word] = dtm[story_id, features.index(word)]
    
    # print words with the top 5 TF-IDF scores
    print 'TOP SCORING WORDS:'
    top_scores = sorted(word_scores.items(), key=lambda x: x[1], reverse=True)[:5]
    for word, score in top_scores:
        print word
    
    # print 5 random words
    print '\n' + 'RANDOM WORDS:'
    random_words = np.random.choice(word_scores.keys(), size=5, replace=False)
    for word in random_words:
        print word
    
    # print the review
    print '\n' + story_text

# %%
# for funsies
summarize()
# Out:
# TOP SCORING WORDS:
# livelihood
# stealin
# springsteen
# class
# overregulation
#
# RANDOM WORDS:
# declare
# sources
# according
# hand
# president
#
# While performing at a campaign rally for President Barack Obama on Thursday, rock icon Bruce Springsteen reportedly failed to fire up the largely working-class audience when he accidentally played an acoustic ballad titled "Big Government's Stealin' Our Livelihood." "Can't ever feed the appetite of Uncle Sam / Stealin' half my paycheck out of my hand," crooned Springsteen, unintentionally alienating the bemused crowd with brazenly pro-market and anti-union lyrics that detail the struggles of a small business owner named Mikey who is forced to declare bankruptcy due to a weak economy plagued by industry overregulation. "Green energy subsidies unfair / The middle class ain't going nowhere / 'Cause that big ol' government stole our livelihood again." According to sources, the New Jersey-bred singer-songwriter only compounded his mistake by following up with the fast-paced rocker "One Man, One Woman."]

# %% [markdown]
# ### Let's do some sentiment analysis.

# %%
# grab a story with Textblob
story = TextBlob(obama.body[0])

# %%
# polarity ranges from -1 (most negative) to 1 (most positive)
story.sentiment.polarity
# Out:
# 0.07462256493506493

# %%
# define a function that accepts text and returns the polarity
def detect_sentiment(text):
    return TextBlob(text.decode('utf-8')).sentiment.polarity

# %%
# create a new DataFrame column for sentiment (can be slow!)
obama['sentiment'] = obama.body.apply(detect_sentiment)

# %%
obama.sentiment.describe()
# Out:
# count    262.000000
# mean       0.083185
# std        0.091416
# min       -0.225980
# 25%        0.015366
# 50%        0.089412
# 75%        0.143657
# max        0.323214
# Name: sentiment, dtype: float64

# %%
# plot sentiment
obama.groupby('tag0').mean().sort_values('sentiment', ascending=False).plot(kind='bar', color='dodgerblue')
plt.xlabel('Primary Content Tag')
plt.ylabel('Average Sentiment')
plt.title('Average Onion Sentiment by Content Tag', y=1.03)
plt.show()

# %%
# create Boolean filter for coloring
(obama.groupby('tag0').mean().sort_values('sentiment', ascending=False)>0).sentiment
# Out:
# tag0
# Family                      True
# World                       True
# War For The White House     True
# Economy                     True
# Survival                    True
# Entertainment               True
# Revenge                     True
# Barack Obama                True
# Crime & Justice             True
# Sports                      True
# Jobs                        True
# Science & Technology        True
# Politics                    True
# News                        True
# Opinion                     True
# Violence                    True
# Business                    True
# Health                      True
# Politicians                 True
# Animals                    False
# Death                      False
# Our Annual Year 2012       False
# Environment                False
# Name: sentiment, dtype: bool

# %%
# plot sentiment, map colors to True/False based on blue/red filter above
obama.groupby('tag0').mean().sort_values('sentiment', ascending=False).plot(kind='bar', color=(obama.groupby('tag0').mean().sort_values('sentiment', ascending=False)>0).sentiment.map({True: 'dodgerblue', False: 'orangered'}))
plt.xlabel('Primary Content Tag')
plt.ylabel('Average Sentiment')
plt.title('Average Onion Sentiment by Content Tag', y=1.03)
plt.legend('')
plt.show()

# %%
# grab max story sentiment
print(str(len(obama[obama.sentiment > .32])) + ' story')
obama[obama.sentiment > .32].head(10)
# Out:
# 1 story
#                                                   link  \
# 237  http://theonion.com/article/obama-praises-own-...
#
#                                                  title       date      tag0  \
# 237  Obama Praises Own Strength, Resilience In Face... 2016-01-12  Politics
#
#             tag1          tag2 tag3 tag4  \
# 237  Politicians  Barack Obama  NaN  NaN
#
#                                                   body    location  sentiment
# 237  Recounting in detail the numerous struggles an...  WASHINGTON   0.323214

# %% [markdown]
# <img src="story-screenshots/obama-positive.png">
#
# [source](http://www.theonion.com/article/obama-praises-own-strength-resilience-face-hardshi-52152)

# %%
# grab min story sentiment
print(str(len(obama[obama.sentiment < -.22])) + ' story')
obama[obama.sentiment < -.22].head(10)
# Out:
# 1 story
#                                                  link  \
# 68  http://theonion.com/article/obama-returns-from...
#
#                                                 title       date      tag0  \
# 68  Obama Returns From India With These Gross Cand... 2010-11-15  Politics
#
#    tag1 tag2 tag3 tag4                                               body  \
# 68  NaN  NaN  NaN  NaN  President Barack Obama returned from a recent ...
#
#       location  sentiment
# 68  WASHINGTON   -0.22598

# %% [markdown]
# <img src="story-screenshots/obama-negative.png">
#
# [source](http://www.theonion.com/article/obama-returns-from-india-with-these-gross-candies--18468)

# %%
# analyze sentiment over time
ts_sent = obama.set_index('date')

# %%
# plot it
ts_sent.plot(color='dodgerblue')
plt.xlabel('Time')
plt.ylabel('Sentiment')

# %%
# let's plot a rolling mean instead; the above is too noisey
fig = plt.figure(figsize=(8, 6))
plt.plot(ts_sent.sentiment.rolling(window=10,center=False).mean(), label='Rolling Mean, 10 Stories', color='dodgerblue')
plt.legend(loc='best')
plt.title("The Onion's Story Sentiment")
plt.ylabel('Story Sentiment')
plt.xlabel('Time')
plt.show()

# %%
# it appears a basketball story and White House hiring a jester story caused this early 2010 happy spike
ts_sent['2010']
# Out:
#                                                          link  \
# date
# 2010-01-11  http://theonion.com/article/obama-to-wait-for-...
# 2010-03-16  http://theonion.com/article/obama-visits-kinde...
# 2010-04-26  http://theonion.com/article/obama-promoted-to-...
# 2010-05-25  http://theonion.com/article/white-house-jester...
# 2010-05-28  http://theonion.com/article/president-obama-me...
# 2010-06-09  http://theonion.com/article/obama-to-make-reas...
# 2010-06-23  http://theonion.com/article/obamas-weekly-vide...
# 2010-07-19  http://theonion.com/article/obamas-fifth-gulf-...
# 2010-07-21  http://theonion.com/article/local-family-homel...
# 2010-08-11  http://theonion.com/article/visiting-chinese-p...
# 2010-08-18  http://theonion.com/article/obama-declares-vic...
# 2010-08-20  http://theonion.com/article/obama-to-create-17...
# 2010-09-22  http://theonion.com/article/poll-1-in-5-americ...
#                                tag2                  tag3  \
# date
# 2011-08-03                      NaN                   NaN
# 2011-08-04                      NaN                   NaN
# 2011-08-10                      NaN                   NaN
# 2011-08-12                      NaN                   NaN
# 2011-09-07                      NaN                   NaN
# 2011-09-09                      NaN                   NaN
# 2011-09-20                      NaN                   NaN
# 2011-10-05                      NaN                   NaN
# 2011-10-12                      Ifc                   NaN
# 2011-11-02                      NaN                   NaN
# 2011-11-07                      NaN                   NaN
# 2011-12-06                      NaN                   NaN
# 2012-01-04              Politicians          Barack Obama
# 2012-01-11              Politicians                   NaN
# 2012-01-12             Barack Obama                   NaN
# 2012-02-01              Politicians          Barack Obama
# 2012-02-08                      NaN                   NaN
# 2012-02-22                      NaN                   NaN
# 2012-03-13     Our Annual Year 2012                   NaN
# 2012-04-04     Our Annual Year 2012                   NaN
# 2012-04-18             Barack Obama  Our Annual Year 2012
# 2012-05-03              Politicians          Barack Obama
# 2012-05-09            Gay & Lesbian          Barack Obama
# 2012-07-10  War For The White House          Barack Obama
# 2012-07-24                      NaN                   NaN
# 2012-08-03                      NaN                   NaN
# 2012-08-09                      NaN                   NaN
# 2012-08-09  War For The White House           Mitt Romney
# 2012-08-23                      NaN                   NaN
# 2012-09-04                      NaN                   NaN
# 2012-09-05  War For The White House          Barack Obama
# 2012-09-06  War For The White House          Barack Obama
# 2012-09-06  War For The White House          Barack Obama
# 2012-09-24             Barack Obama  Our Annual Year 2012
# 2012-10-01             Barack Obama                   NaN
# 2012-10-02             Barack Obama                   NaN
# 2012-10-03             Barack Obama                   NaN
# 2012-10-04             Barack Obama  Our Annual Year 2012
# 2012-10-15             Barack Obama                   NaN
# 2012-10-16  War For The White House                   NaN
# 2012-10-18                      NaN                   NaN
# 2012-10-22             Barack Obama  Our Annual Year 2012
# 2012-10-22     Our Annual Year 2012                   NaN
# 2012-10-25                      NaN                   NaN
# 2012-11-01                      NaN                   NaN
# 2012-11-06  War For The White House          Barack Obama
# 2012-11-06                      NaN                   NaN
# 2012-11-07              Mitt Romney          Barack Obama
# 2012-12-06                      NaN                   NaN
#
#                             tag4  \
# date
# 2011-08-03                   NaN
# 2011-08-04                   NaN
# 2011-08-10                   NaN
# 2011-08-12                   NaN
# 2011-09-07                   NaN
# 2011-09-09                   NaN
# 2011-09-20                   NaN
# 2011-10-05                   NaN
# 2011-10-12                   NaN
# 2011-11-02                   NaN
# 2011-11-07                   NaN
# 2011-12-06                   NaN
# 2012-01-04                   NaN
# 2012-01-11                   NaN
# 2012-01-12                   NaN
# 2012-02-01                   NaN
# 2012-02-08                   NaN
# 2012-02-22                   NaN
# 2012-03-13                   NaN
# 2012-04-04                   NaN
# 2012-04-18                   NaN
# 2012-05-03                   NaN
# 2012-05-09  Our Annual Year 2012
# 2012-07-10                   NaN
# 2012-07-24                   NaN
# 2012-08-03                   NaN
# 2012-08-09                   NaN
# 2012-08-09                   NaN
# 2012-08-23                   NaN
# 2012-09-04                   NaN
# 2012-09-05                   NaN
# 2012-09-06  Our Annual Year 2012
# 2011-08-04                               WASHINGTON   0.020408
# 2011-08-10                               WASHINGTON   0.061862
# 2011-08-12                               WASHINGTON   0.194949
# 2011-09-07                               WASHINGTON   0.219320
# 2011-09-09                               WASHINGTON   0.138799
# 2011-09-20                             COLUMBIA, SC   0.099495
# 2011-10-05                         GRAND RAPIDS, MI   0.078526
# 2011-10-12                                      NaN   0.197869
# 2011-11-02                               WASHINGTON   0.124235
# 2011-11-07                               WASHINGTON  -0.009349
# 2011-12-06                               CINCINNATI  -0.076282
# 2012-01-04                               PITTSBURGH   0.002841
# 2012-01-11                               WASHINGTON   0.095455
# 2012-01-12                               WASHINGTON  -0.093750
# 2012-02-01                               WASHINGTON   0.134548
# 2012-02-08                               WASHINGTON   0.107448
# 2012-02-22                               WASHINGTON   0.070952
# 2012-03-13                               WASHINGTON  -0.131968
# 2012-04-04                               WASHINGTON  -0.010379
# 2012-04-18                                  CHICAGO   0.082027
# 2012-05-03                               WASHINGTON   0.143892
# 2012-05-09                               WASHINGTON   0.100093
# 2012-07-10                               WASHINGTON   0.003805
# 2012-07-24                                      NaN   0.027737
# 2012-08-03                             HENNIKER, NH   0.136458
# 2012-08-09                         WEST LEBANON, NH  -0.041111
# 2012-08-09                                  CHICAGO   0.158740
# 2012-08-23                          NEW BRITAIN, CT   0.132397
# 2012-09-04                                      NaN   0.136059
# 2012-09-05                            COVINGTON, KY   0.161111
# 2012-09-06                            CHARLOTTE, NC   0.167337
# 2012-09-06                            CHARLOTTE, NC  -0.009261
# 2012-09-24                           CHARLESTON, WV   0.092708
# 2012-10-01                             COLUMBUS, OH   0.088447
# 2012-10-02  EVERYWHERE IN SPACE-TIME SIMULTANEOUSLY   0.101547
# 2012-10-03                                   DENVER   0.238889
# 2012-10-04                                   DENVER   0.013965
# 2012-10-15                               WASHINGTON   0.178838
# 2012-10-16                            HEMPSTEAD, NY   0.114353
# 2012-10-18                                PARMA, OH  -0.147876
# 2012-10-22                           BOCA RATON, FL   0.001325
# 2012-10-22                           BOCA RATON, FL   0.017276
# 2012-10-25                                      NaN   0.048511
# 2012-11-01                                      NaN   0.101376
# 2012-11-06                               WASHINGTON   0.005519
# 2012-11-06                                  CHICAGO   0.112337
# 2012-11-07                               WASHINGTON   0.112500
# 2012-12-06                               WASHINGTON   0.052023

# %% [markdown]
# ## Build a model to determine if a story was first or second term

# %%
# list comprehension to make 0 for first term, 1 for second term
obama['second_term'] = [1 if datetime.date(obama.date[i].year, obama.date[i].month, obama.date[i].day) >= datetime.date(2013, 1, 20) else 0 for i,x in enumerate(obama.date)]

# %%
# verify list comprehension success
obama.second_term.value_counts()
# Out:
# 0    134
# 1    128
# Name: second_term, dtype: int64

# %%
# define X and y
X = obama.body
y = obama.second_term

# split the new DataFrame into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# vectorizer used earlier with blue graphs - simple counts
vect = CountVectorizer(ngram_range=(1, 2), stop_words='english', min_df=2)

# %%
# use vectorizer created above to create document-term matrices from X_train and X_test
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)

# %% [markdown]
# ### Naive Bayes
#
# For an introduction to Naive Bayes and text data, check out [Sebastian Rashcka](http://sebastianraschka.com/Articles/2014_naive_bayes_1.html)

# %%
# use Naive Bayes to predict term
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)

# calculate accuracy
print metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.727272727273

# %%
# calculate null accuracy
y_test_binary = np.where(y_test==0, 1, 0)
max(y_test_binary.mean(), 1 - y_test_binary.mean())
# Out:
# 0.53030303030303028

# %% [markdown]
# **A 20% lift vs null accuracy isn't too bad!**

# %% [markdown]
# ### Support Vector Machine
#
# Support vector machines work well on text data becuase:
# - Reduces risk of overfitting in high dimension input space
# - Similarly, trains on few irrelevant features
# - Document vectors are sparse
# - Our text categorization problem is linearly separable
#
# More info on a paper (Joachims, 1998) cited 8000+ times on this is [here](https://www.cs.cornell.edu/people/tj/publications/joachims_98a.pdf).
#
# For a tutorial on SVMs, check [svm-tutorial.com](http://www.svm-tutorial.com/2014/11/svm-understanding-math-part-1/)

# %%
# SUPER SLOWLY and lazily going to check every parameter for an SVM on my text data
clf = svm.SVC()
gamma_range = 10.**np.arange(-5, 2)
C_range = 10.**np.arange(-2, 3)
kernel_range = ['rbf', 'sigmoid', 'linear', 'poly']
param_grid = dict(gamma=gamma_range, C=C_range, kernel=kernel_range)
grid = GridSearchCV(clf, param_grid, cv=10, scoring='accuracy')
grid.fit(X_train_dtm, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'kernel': ['rbf', 'sigmoid', 'linear', 'poly'], 'C': array([  1.00000e-02,   1.00000e-01,   1.00000e+00,   1.00000e+01,
#          1.00000e+02]), 'gamma': array([  1.00000e-05,   1.00000e-04,   1.00000e-03,   1.00000e-02,
#          1.00000e-01,   1.00000e+00,   1.00000e+01])},
#        pre_dispatch='2*n_jobs', refit=True, scoring='accuracy', verbose=0)

# %%
# what was best?
print grid.best_score_
print grid.best_params_
print grid.best_estimator_
# Out:
# 0.739795918367
# {'kernel': 'linear', 'C': 0.01, 'gamma': 1.0000000000000001e-05}
# SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=1.0000000000000001e-05,
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# Even after all of that SVM training, we improved over Naive Bayes by like 2%. But hey...
# **A 20% lift vs null accuracy isn't too bad!**

# %% [markdown]
# ### Random Forest
#
# Given the high dimensions of our features (very wide compared to long), a random forest will likely be quite poor.
#
# However, random forests enable us to easily identify various feature importances. In this case, we will be able to see which words are most dilenating between Obama's first and second terms in The Onion's coverage.

# %%
from sklearn.ensemble import RandomForestClassifier
rf_grid = RandomForestClassifier(random_state=99, n_jobs=50)

# %%
#Parameter dictionary of settings options for the model we're passing grid search.
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : [None,2,5,8],
    'max_features' : ['auto', 'sqrt', 'log2'],
    'class_weight' : ['balanced', None]
}

# %%
#Instantiate grid search.
grid = GridSearchCV(rf_grid, param_grid, cv=5, scoring='accuracy')

#Fit the grid search to X, and y.
grid.fit(X_train_dtm, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=50,
#             oob_score=False, random_state=99, verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'max_features': ['auto', 'sqrt', 'log2'], 'criterion': ['gini', 'entropy'], 'max_depth': [None, 2, 5, 8], 'class_weight': ['balanced', None]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='accuracy', verbose=0)

# %%
#Store the best parameters in a variable.
params = grid.best_params_
print "Best score =", grid.best_score_
print params
# Out:
# Best score = 0.642857142857
# {'max_features': 'auto', 'criterion': 'entropy', 'max_depth': None, 'class_weight': None}

# %%
#Run Random Forest on the data.
rf = RandomForestClassifier(**params)
rf_model = rf.fit(X_train_dtm, y_train)
y_pred = rf.predict(X_test_dtm)

print "RandomForest Cross_Val Score:\t", cross_val_score(rf, X_train_dtm, y_train, cv=5).mean()
print "Train/Test RandomForest Score:\t", rf.score(X_test_dtm, y_test)
# Out:
# RandomForest Cross_Val Score:	0.597078272605
# Train/Test RandomForest Score:	0.727272727273

# %% [markdown]
# Indeed, a random forest is not the best choice.

# %%
# create dataframe showing feature importances of rf
df_features = pd.DataFrame(columns=['Features', 'Importance (Gini Index)'])
df_features['Features'] = columns=vect.get_feature_names()
df_features['Importance (Gini Index)'] = rf.feature_importances_
df_features.sort_values('Importance (Gini Index)', ascending=False, inplace=True)

# %%
# top 10 features
df_features.head(10)
# Out:
#               Features  Importance (Gini Index)
# 3962         president                 0.015303
# 3117           massive                 0.010452
# 3256       mitt romney                 0.010084
# 856          candidate                 0.009971
# 5036        strategist                 0.009837
# 4005      presidential                 0.009570
# 2315             hands                 0.008529
# 1299        criticized                 0.007976
# 3386             needs                 0.007690
# 400   announced monday                 0.007286

# %%
# plot most important features
df_features.head(10).plot(kind='bar', x='Features', color='dodgerblue')
plt.ylabel('Gini Index')
plt.xlabel('')
plt.title("Most Distinguishing Words Between Obama's First and Second Terms", y=1.03)

# %% [markdown]
# ### Try playing with different vectorizers using Naive Bayes to improve accuracy:

# %%
# define a function that accepts a vectorizer and calculates the accuracy
def tokenize_test(vect):
    X_train_dtm = vect.fit_transform(X_train)
    print 'Features: ', X_train_dtm.shape[1]
    X_test_dtm = vect.transform(X_test)
    nb = MultinomialNB()
    nb.fit(X_train_dtm, y_train)
    y_pred_class = nb.predict(X_test_dtm)
    print 'Accuracy: ', metrics.accuracy_score(y_test, y_pred_class)

# %%
# include 1-grams and 2-grams
vect = CountVectorizer(ngram_range=(1, 2))
tokenize_test(vect)
# Out:
# Features:  58752
# Accuracy:  0.787878787879

# %%
# remove English stop words
vect = CountVectorizer(ngram_range=(1, 2), stop_words='english')
tokenize_test(vect)
# Out:
# Features:  44970
# Accuracy:  0.80303030303

# %% [markdown]
# **High score!**

# %% [markdown]
# Final results suggest the most powerful model is a Naive Bayes classifier with an ngram range of 1 to 2 and English stopword removal. This model achieved a ~30% lift over the null accuracy: 80% vs 53%.

# %%
# dig deeper: confusion matrix 
conmat = np.array(confusion_matrix(y_test, y_pred_class, labels=[1,0]))
confusion = pd.DataFrame(conmat, index=['term_two', 'term_one'],
                         columns=['predicted_term_two','predicted_term_one'])
print(confusion)
# Out:
#           predicted_term_two  predicted_term_one
# term_two                  23                   8
# term_one                  10                  25

# %% [markdown]
# Based on the confusion matrix, false positives (predicted an article was from the second term but it was actually from the first term) and false negatives (predicted an article was from the first term, but it was actually from the second term) are relatively controlled. I am indifferent to minimizing type one error vs type two error in this case, so aiming for highest accuracy regardless of error type is satisfactory.
